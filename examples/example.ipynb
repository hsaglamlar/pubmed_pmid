# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.path.dirname("__file__"), "..")))

# %%
import logging
from src.utils.logging_config import configure_logging

configure_logging(level="ERROR", log_file="example.log")
logger = logging.getLogger(__name__)

# %%
import json
from src.parsers.pubmed_parser import PubmedParser

# %%
pubmed = PubmedParser(get_citation_count_bool=True, get_journal_ranking_bool=True, log_level="ERROR")

# %% [markdown]
# # Example of using the PubmedParser with PubmedID

# %%
pubmed.build_pubmed_json_from_pmid("36464825")
# Out:
# {'abstract': [{'text': '\n\nBACKGROUND/AIMS:\nEndoscopic submucosal dissection (ESD) is an effective method for resecting gastric adenomas and adenocarcinomas. A significant discrepancy was observed between endoscopic and pathological sizes in samples obtained from patients undergoing ESD. This study elucidates the factors affecting size discrepancy after formalin fixation.\n\n\nMETHODS:\nThe records of 64 patients with 69 lesions were analyzed, including 50 adenomas and 19 adenocarcinomas. Data on location, gross shape, histology, and size after fixation in formalin were collected.\n\n\nRESULTS:\nThe mean size of the resected specimen appeared to decrease after formalin fixation (37.5 mm prefixation vs. 35.8 mm postfixation, p<0.05). The mean long axis diameter of the lesions was 20.3±7.9 mm prefixation and 13.4±7.9 mm postfixation. Size differences in lesions smaller than 20 mm were significantly greater than those in lesions larger than 20 mm (7.6±5.6 mm vs. 2.5±5.8 mm, p<0.01). In multivariate analysis, a tumor size of ≥20 mm was found to be an independent factor affecting size postformalin fixation (p<0.05).\n\n\nCONCLUSION:\nThe endoscopic size of lesions before ESD may be underestimated in tumors larger than 20 mm in size. Therefore, increased attention must be paid during ESD to avoid instances of incomplete resection.',
#    'section_title': 'Abstract',
#    'section_type': 'ABSTRACT'}],
#  'meta_info': {'articleids': [{'idtype': 'pubmed', 'value': '36464825'},
#    {'idtype': 'pmc', 'value': 'PMC9726444'},
#    {'idtype': 'doi', 'value': '10.5946/ce.2021.269'},
#    {'idtype': 'pii', 'value': 'ce.2021.269'}],
#   'kwd': 'Endoscopic submucosal dissection;Endoscopy;Stomach neoplasms',
#   'dates_history': [{'date_type': 'received',
#     'year': '2021',
#     'month': '11',
#     'day': '3'},
#    {'date_type': 'accepted', 'year': '2022', 'month': '2', 'day': '9'},
#    {'date_type': 'entrez', 'year': '2022', 'month': '12', 'day': '5'},
#    {'date_type': 'pubmed', 'year': '2022', 'month': '12', 'day': '6'},
#    {'date_type': 'medline', 'year': '2022', 'month': '12', 'day': '6'},
#    {'date_type': 'pmc-release', 'year': '2022', 'month': '11', 'day': '1'}],
#   'fulljournalname': 'Clinical endoscopy',
#   'journal_abbrev': 'Clin Endosc',
#   'issn': '2234-2400',
#   'pubdate': '2022 Nov',
#   'title': 'Underestimation of endoscopic size in large gastric epithelial neoplasms.',
#   'languages': 'eng',
#   'volume': '55',
#   'issue': '6',
#   'pages': '760-766',
#   'publication_type': [('D016428', 'Journal Article')],
#   'authors': [{'first': 'Jae Sun',
#     'middle': '',
#     'last': 'Song',
#     'suffix': '',
#     'initials': 'JS',
#     'affiliation': 'Division of Gastroenterology, Department of Internal Medicine, Presbyterian Medical Center, Jeonju, Korea.',
#     'email': ''},
#    {'first': 'Byung Sun',
#     'middle': '',
#     'last': 'Kim',
#     'suffix': '',
#     'initials': 'BS',
#     'affiliation': 'Division of Gastroenterology, Department of Internal Medicine, Presbyterian Medical Center, Jeonju, Korea.',
#     'email': ''},
#    {'first': 'Min A',
#     'middle': '',
#     'last': 'Yang',
#     'suffix': '',
#     'initials': 'MA',
#     'affiliation': 'Division of Gastroenterology, Department of Internal Medicine, Presbyterian Medical Center, Jeonju, Korea.',
#     'email': ''},
#    {'first': 'Young Jae',
#     'middle': '',
#     'last': 'Lee',
#     'suffix': '',
#     'initials': 'YJ',
#     'affiliation': 'Division of Gastroenterology, Department of Internal Medicine, Presbyterian Medical Center, Jeonju, Korea.',
#     'email': ''},
#    {'first': 'Gum Mo',
#     'middle': '',
#     'last': 'Jung',
#     'suffix': '',
#     'initials': 'GM',
#     'affiliation': 'Division of Gastroenterology, Department of Internal Medicine, Presbyterian Medical Center, Jeonju, Korea.',
#     'email': ''},
#    {'first': 'Ji Woong',
#     'middle': '',
#     'last': 'Kim',
#     'suffix': '',
#     'initials': 'JW',
#     'affiliation': 'Division of Gastroenterology, Department of Internal Medicine, Presbyterian Medical Center, Jeonju, Korea.',
#     'email': ''},
#    {'first': 'Jin Woong',
#     'middle': '',
#     'last': 'Cho',
#     'suffix': '',
#     'initials': 'JW',
#     'affiliation': 'Division of Gastroenterology, Department of Internal Medicine, Presbyterian Medical Center, Jeonju, Korea.',
#     'email': ''}],
#   'mesh_terms': '',
#   'citation_count': 1,
#   'journal_ranking': {'Journal': 'Journal of Clinical Investigation',
#    'Articles': 39700,
#    'Citations': 4200000,
#    'Impact Factor': 8.2}},
#  'pmid': '36464825',
#  'article_splits': [{'text': 'BACKGROUND/AIMS:\nEndoscopic submucosal dissection (ESD) is an effective method for resecting gastric adenomas and adenocarcinomas. A significant discrepancy was observed between endoscopic and pathological sizes in samples obtained from patients undergoing ESD. This study elucidates the factors affecting size discrepancy after formalin fixation.\n\n\nMETHODS:\nThe records of 64 patients with 69 lesions were analyzed, including 50 adenomas and 19 adenocarcinomas. Data on location, gross shape, histology, and size after fixation in formalin were collected.\n\n\nRESULTS: The mean size of the resected specimen appeared to decrease after formalin fixation (37.5 mm prefixation vs. 35.8 mm postfixation, p<0.05). The mean long axis diameter of the lesions was 20.3±7.9 mm prefixation and 13.4±7.9 mm postfixation. Size differences in lesions smaller than 20 mm were significantly greater than those in lesions larger than 20 mm (7.6±5.6 mm vs. 2.5±5.8 mm, p<0.01). In multivariate analysis, a tumor size of ≥20 mm was found to be an independent factor affecting size postformalin fixation (p<0.05). CONCLUSION: The endoscopic size of lesions before ESD may be underestimated in tumors larger than 20 mm in size. Therefore, increased attention must be paid during ESD to avoid instances of incomplete resection.',
#    'section_title': 'Abstract',
#    'section_type': 'ABSTRACT',
#    'split_number': 1,
#    'total_splits': 1}]}

# %% [markdown]
# # Fetch the xml file from pubmed API

# %%
pubmed_xml = pubmed.get_pubmed_article_xml("36464825")
print(pubmed_xml)
# Out:
# <?xml version="1.0" ?>
# <!DOCTYPE PubmedArticleSet PUBLIC "-//NLM//DTD PubMedArticle, 1st January 2025//EN" "https://dtd.nlm.nih.gov/ncbi/pubmed/out/pubmed_250101.dtd">
# <PubmedArticleSet>
# <PubmedArticle><MedlineCitation Status="PubMed-not-MEDLINE" Owner="NLM"><PMID Version="1">36464825</PMID><DateRevised><Year>2022</Year><Month>12</Month><Day>14</Day></DateRevised><Article PubModel="Print-Electronic"><Journal><ISSN IssnType="Print">2234-2400</ISSN><JournalIssue CitedMedium="Print"><Volume>55</Volume><Issue>6</Issue><PubDate><Year>2022</Year><Month>Nov</Month></PubDate></JournalIssue><Title>Clinical endoscopy</Title><ISOAbbreviation>Clin Endosc</ISOAbbreviation></Journal><ArticleTitle>Underestimation of endoscopic size in large gastric epithelial neoplasms.</ArticleTitle><Pagination><StartPage>760</StartPage><EndPage>766</EndPage><MedlinePgn>760-766</MedlinePgn></Pagination><ELocationID EIdType="doi" ValidYN="Y">10.5946/ce.2021.269</ELocationID><Abstract><AbstractText Label="BACKGROUND/AIMS" NlmCategory="OBJECTIVE">Endoscopic submucosal dissection (ESD) is an effective method for resecting gastric adenomas and adenocarcinomas. A significant discrepancy was observed between endoscopic and pathological sizes in samples obtained from patients undergoing ESD. This study elucidates the factors affecting size discrepancy after formalin fixation.</AbstractText><AbstractText Label="METHODS" NlmCategory="METHODS">The records of 64 patients with 69 lesions were analyzed, including 50 adenomas and 19 adenocarcinomas. Data on location, gross shape, histology, and size after fixation in formalin were collected.</AbstractText><AbstractText Label="RESULTS" NlmCategory="RESULTS">The mean size of the resected specimen appeared to decrease after formalin fixation (37.5 mm prefixation vs. 35.8 mm postfixation, p&lt;0.05). The mean long axis diameter of the lesions was 20.3&#xb1;7.9 mm prefixation and 13.4&#xb1;7.9 mm postfixation. Size differences in lesions smaller than 20 mm were significantly greater than those in lesions larger than 20 mm (7.6&#xb1;5.6 mm vs. 2.5&#xb1;5.8 mm, p&lt;0.01). In multivariate analysis, a tumor size of &#x2265;20 mm was found to be an independent factor affecting size postformalin fixation (p&lt;0.05).</AbstractText><AbstractText Label="CONCLUSION" NlmCategory="CONCLUSIONS">The endoscopic size of lesions before ESD may be underestimated in tumors larger than 20 mm in size. Therefore, increased attention must be paid during ESD to avoid instances of incomplete resection.</AbstractText></Abstract><AuthorList CompleteYN="Y"><Author ValidYN="Y"><LastName>Song</LastName><ForeName>Jae Sun</ForeName><Initials>JS</Initials><AffiliationInfo><Affiliation>Division of Gastroenterology, Department of Internal Medicine, Presbyterian Medical Center, Jeonju, Korea.</Affiliation></AffiliationInfo></Author><Author ValidYN="Y"><LastName>Kim</LastName><ForeName>Byung Sun</ForeName><Initials>BS</Initials><AffiliationInfo><Affiliation>Division of Gastroenterology, Department of Internal Medicine, Presbyterian Medical Center, Jeonju, Korea.</Affiliation></AffiliationInfo></Author><Author ValidYN="Y"><LastName>Yang</LastName><ForeName>Min A</ForeName><Initials>MA</Initials><AffiliationInfo><Affiliation>Division of Gastroenterology, Department of Internal Medicine, Presbyterian Medical Center, Jeonju, Korea.</Affiliation></AffiliationInfo></Author><Author ValidYN="Y"><LastName>Lee</LastName><ForeName>Young Jae</ForeName><Initials>YJ</Initials><Aff
scopic submucosal dissection in patients with early gastric cancer. Gastrointest Endosc. 2017;85:976&#x2013;983.</Citation><ArticleIdList><ArticleId IdType="pubmed">27756614</ArticleId></ArticleIdList></Reference><Reference><Citation>Gotoda T, Yanagisawa A, Sasako M, et al. Incidence of lymph node metastasis from early gastric cancer: estimation with a large number of cases at two large centers. Gastric Cancer. 2000;3:219&#x2013;225.</Citation><ArticleIdList><ArticleId IdType="pubmed">11984739</ArticleId></ArticleIdList></Reference><Reference><Citation>Cho JW. The role of endosonography in the staging of gastrointestinal cancers. Clin Endosc. 2015;48:297&#x2013;301.</Citation><ArticleIdList><ArticleId IdType="pmc">PMC4522420</ArticleId><ArticleId IdType="pubmed">26240802</ArticleId></ArticleIdList></Reference><Reference><Citation>Shim CN, Song MK, Kang DR, et al. Size discrepancy between endoscopic size and pathologic size is not negligible in endoscopic resection for early gastric cancer. Surg Endosc. 2014;28:2199&#x2013;2207.</Citation><ArticleIdList><ArticleId IdType="pubmed">24519032</ArticleId></ArticleIdList></Reference><Reference><Citation>Asada-Hirayama I, Kodashima S, Goto O, et al. Factors predictive of inaccurate determination of horizontal extent of intestinal-type early gastric cancers during endoscopic submucosal dissection: a retrospective analysis. Dig Endosc. 2013;25:593&#x2013;600.</Citation><ArticleIdList><ArticleId  ...

# %% [markdown]
# # Process a single xml file

# %%
# get citation count and journal ranking from APIs
pubmed = PubmedParser(get_citation_count_bool=True, get_journal_ranking_bool=True)

# %%
# use a single article as xml file
formatted_json = pubmed.build_pubmed_json(
    "example xml/temp_3.xml",
)
formatted_json
# Out:
# {'abstract': [{'text': 'Switch-based adaptive dynamic programming (ADP) is an optimal control problem in which a cost must be minimized by switching among a family of dynamical modes. When the system dimension increases, the solution to switch-based ADP is made prohibitive by the exponentially increasing structure of the value function approximator and by the exponentially increasing modes. This technical correspondence proposes a distributed computational method for solving switch-based ADP. The method relies on partitioning the system into agents, each one dealing with a lower dimensional state and a few local modes. Each agent aims to minimize a local version of the global cost while avoiding that its local switching strategy has conflicts with the switching strategies of the neighboring agents. A heuristic algorithm based on the consensus dynamics and Nash equilibrium is proposed to avoid such conflicts. The effectiveness of the proposed method is verified via traffic and building test cases.',
#    'section_title': 'Abstract',
#    'section_type': 'ABSTRACT'}],
#  'meta_info': {'articleids': [{'idtype': 'pubmed', 'value': '33156801'},
#    {'idtype': 'doi', 'value': '10.1109/TCYB.2020.3029825'}],
#   'kwd': '',
#   'dates_history': [{'date_type': 'pubmed',
#     'year': '2020',
#     'month': '11',
#     'day': '7'},
#    {'date_type': 'medline', 'year': '2022', 'month': '7', 'day': '7'},
#    {'date_type': 'entrez', 'year': '2020', 'month': '11', 'day': '6'}],
#   'fulljournalname': 'IEEE transactions on cybernetics',
#   'journal_abbrev': 'IEEE Trans Cybern',
#   'issn': '2168-2275',
#   'pubdate': '2022 Jul',
#   'title': 'On Distributed Implementation of Switch-Based Adaptive Dynamic Programming.',
#   'languages': 'eng',
#   'volume': '52',
#   'issue': '7',
#   'pages': '7218-7224',
#   'publication_type': [('D016428', 'Journal Article')],
#   'authors': [{'first': 'Di',
#     'middle': '',
#     'last': 'Liu',
#     'suffix': '',
#     'initials': 'D',
#     'affiliation': '',
#     'email': ''},
#    {'first': 'Simone',
#     'middle': '',
#     'last': 'Baldi',
#     'suffix': '',
#     'initials': 'S',
#     'affiliation': '',
#     'email': ''},
#    {'first': 'Wenwu',
#     'middle': '',
#     'last': 'Yu',
#     'suffix': '',
#     'initials': 'W',
#     'affiliation': '',
#     'email': ''},
#    {'first': 'Guanrong',
#     'middle': '',
#     'last': 'Chen',
#     'suffix': '',
#     'initials': 'G',
#     'affiliation': '',
#     'email': ''}],
#   'mesh_terms': 'D000465:Algorithms*;D003198:Computer Simulation;D017711:Nonlinear Dynamics*',
#   'citation_count': 20,
#   'journal_ranking': {'Journal': 'IEEE Transactions on Antennas and Propagation',
#    'Articles': 22700,
#    'Citations': 741800,
#    'Impact Factor': 5.3}},
#  'pmid': '33156801',
#  'article_splits': [{'text': 'Switch-based adaptive dynamic programming (ADP) is an optimal control problem in which a cost must be minimized by switching among a family of dynamical modes. When the system dimension increases, the solution to switch-based ADP is made prohibitive by the exponentially increasing structure of the value function approximator and by the exponentially increasing modes. This technical correspondence proposes a distributed computational method for solving switch-based ADP. The method relies on partitioning the system into agents, each one dealing with a lower dimensional state and a few local modes. Each agent aims to minimize a local version of the global cost while avoiding that its local switching strategy has conflicts with the switching strategies of the neighboring agents. A heuristic algorithm based on the consensus dynamics and Nash equilibrium is proposed to avoid such conflicts. The effectiveness of the proposed method is verified via traffic and building test cases.',
#    'section_title': 'Abstract',
#    'section_type': 'ABSTRACT',
#    'split_number': 1,
#    'total_splits': 1}]}

# %% [markdown]
# # Process a large xml gz file that contains more than around 5000 articles

# %%
# these large xml files are from https://ftp.ncbi.nlm.nih.gov/pubmed/baseline/
pubmed = PubmedParser(get_citation_count_bool=False, get_journal_ranking_bool=False)

dicts_out = pubmed.parse_pubmed_xml_iter("../data/pubmed23n1181.xml.gz")

save_path = "../data/pubmed"
if not os.path.exists(save_path):
    os.makedirs(save_path)

for article in dicts_out:
    if article is None:
        continue
    pmid = article["pmid"]
    with open(f"{save_path}/pubmed_{pmid}.json", "w") as f:
        json.dump(article, f)
# Out:
# 2025-05-19 23:11:08,838 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32297852
# 2025-05-19 23:11:09,320 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32372739
# 2025-05-19 23:11:09,405 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32412552
# 2025-05-19 23:11:09,462 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32437920
# 2025-05-19 23:11:09,555 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32456735
# 2025-05-19 23:11:09,555 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32454071
# 2025-05-19 23:11:10,091 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32502524
# 2025-05-19 23:11:10,091 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32505468
# 2025-05-19 23:11:10,091 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32505472
# 2025-05-19 23:11:10,238 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32505474
# 2025-05-19 23:11:10,704 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32544570
# 2025-05-19 23:11:10,856 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32603673
# 2025-05-19 23:11:11,006 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32635951
# 2025-05-19 23:11:11,087 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32693926
# 2025-05-19 23:11:11,087 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32739226
# 2025-05-19 23:11:11,339 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32807557
# 2025-05-19 23:11:11,339 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32811685
# 2025-05-19 23:11:11,417 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32819796
# 2025-05-19 23:11:11,422 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32829987
# 2025-05-19 23:11:11,458 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 32839054
# 2025-05-19 23:11:11,474 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article
- src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35738967
# 2025-05-19 23:12:17,667 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35750530
# 2025-05-19 23:12:17,774 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35753842
# 2025-05-19 23:12:17,890 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35757816
# 2025-05-19 23:12:18,410 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35772437
# 2025-05-19 23:12:19,410 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35809051
# 2025-05-19 23:12:20,575 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35840463
# 2025-05-19 23:12:21,995 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35868494
# 2025-05-19 23:12:22,099 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35870344
# 2025-05-19 23:12:22,145 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35870703
# 2025-05-19 23:12:22,148 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35870738
# 2025-05-19 23:12:22,829 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35879198
# 2025-05-19 23:12:23,135 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35894635
# 2025-05-19 23:12:23,445 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35906988
# 2025-05-19 23:12:24,127 - src.parsers.pubmed_parser - INFO - No abstract found in pubmed article 35917755
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 10
#       7 if not os.path.exists(save_path):
#       8     os.makedirs(save_path)
# ---> 10 for article in dicts_out:
#      11     if article is None:
#      12         continue
#
# File c:\Users\halil\Documents\github\pubmed_pmid\pubmed_pmid\src\parsers\pubmed_parser.py:288, in PubmedParser.parse_pubmed_xml_iter(self, path)
#     286 for _, element in etree.iterparse(f, events=("end",)):
#     287     if element.tag == "PubmedArticle":
# --> 288         res = self.build_pubmed_json(xml_tree=element)
#     289         element.clear()
#     290         yield res
#
# File c:\Users\halil\Documents\github\pubmed_pmid\pubmed_pmid\src\parsers\pubmed_parser.py:204, in PubmedParser.build_pubmed_json(self, xml_path, xml_tree)
#     201 json_output["pmid"] = pmid
#     203 # Get the article splits
# --> 204 json_output["article_splits"] = split_article_paragraphs(
#     205     json_output,
#     206     self.max_split_token_length,
#     207     self.min_split_token_length,
#     208     self.sentence_overlap,
#     209 )
#     211 # Get the citation count of the article
#     212 if self.citation_count_bool:
#
# File c:\Users\halil\Documents\github\pubmed_pmid\pubmed_pmid\src\utils\article_splitter.py:52, in split_article_paragraphs(article_json, max_split_token_length, min_split_token_length, sentence_overlap)
#      49     continue
#      51 # Get sentences from section text
# ---> 52 sentences = get_sentences(section_text)
#      53 if not sentences:
#      54     logger.warning(
#      55         "No sentences found in section: %s",
#      56         section.get("section_title", "Unknown"),
#      57     )
#
# File c:\Users\halil\Documents\github\pubmed_pmid\pubmed_pmid\src\utils\detect_sentences.py:45, in get_sentences(text)
#      42     return []
#      44 try:
# ---> 45     doc = nlp(text)
#      46     sentences = [sent.text.strip() for sent in doc.sents if sent.text.strip()]
#      47     logger.debug("Extracted %d sentences from text", len(sentences))
#
# File c:\Users\halil\Documents\github\pubmed_pmid\pubmed_pmid\.venv\Lib\site-packages\spacy\language.py:1052, in Language.__call__(self, text, disable, component_cfg)
#    1050     error_handler = proc.get_error_handler()
#    1051 try:
# -> 1052     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1053 except KeyError as e:
#    1054     # This typically happens if a component is not initialized
#    1055     raise ValueError(Errors.E109.format(name=name)) from e
#
# KeyboardInterrupt:

# %%
# remove save path

import shutil

# Check if it exists before attempting to remove
if os.path.exists(save_path):
	try:
		# Use rmtree to remove directory and all its contents
		shutil.rmtree(save_path)
		print(f"Successfully removed {save_path}")
	except Exception as e:
		print(f"Error removing directory: {e}")
else:
	print(f"Path {save_path} does not exist")
# Out:
# Successfully removed ../data/pubmed
